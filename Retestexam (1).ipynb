# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\rohan\Downloads\Employee.csv")
data.head()
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                   2.0
# 1              Poor             High                Low                   3.0
# 2              Good             High                Low                   0.0
# 3              Good             High               High                   1.0
# 4              Fair        Very High            Average                   0.0
#
# ...

# %%
data_test = pd.read_csv(r"C:\Users\rohan\Downloads\Employee.csv")
data.head()
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                   2.0
# 1              Poor             High                Low                   3.0
# 2              Good             High                Low                   0.0
# 3              Good             High               High                   1.0
# 4              Fair        Very High            Average                   0.0
#
# ...

# %%
data.sample(5)
# Out:
#        Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 55938          718   55  Female                32  Healthcare            8465
# 68915        66795   56  Female                39  Healthcare            6983
# 73138        56317   19    Male                11  Healthcare            7112
# 60070        44804   26    Male                10  Healthcare            7201
# 10845        74496   51    Male                42   Education            4124
#
#       Work-Life Balance Job Satisfaction Performance Rating  \
# 55938              Good           Medium            Average
# 68915         Excellent           Medium            Average
# 73138              Good             High               High
# 60070              Poor             High                Low
# 10845              Fair           Medium            Average
#
#        Number of Promotions  ... Number of Dependents  Job Level Company Size  \
# ...

# %%
data.shape
# Out:
# (74498, 24)

# %%
data.info
# Out:
# <bound method DataFrame.info of        Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0             8410   31    Male                19   Education            5390
# 1            64756   59  Female                 4       Media            5534
# 2            30257   24  Female                10  Healthcare            8159
# 3            65791   36  Female                 7   Education            3989
# 4            65026   56    Male                41   Education            4821
# ...            ...  ...     ...               ...         ...             ...
# 74493        16243   56  Female                42  Healthcare            7830
# 74494        47175   30  Female                15   Education            3856
# 74495        12409   52    Male                 5   Education            5654
# 74496         9554   18    Male                 4   Education            5276
# 74497        73042   59  Female                48   Education            3774
#
# ...

# %%
data.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data.columns
#
# NameError: name 'data' is not defined

# %%
data.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data.dtypes
#
# NameError: name 'data' is not defined

# %%
corrmat = data.corr()
plt.subplots(figsize = (10,9))
sns.heatmap(corrmat, annot = True,vmin= -0.2, vmax = 0.9, cmap = 'Job Role')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 corrmat = data.corr()
#       2 plt.subplots(figsize = (10,9))
#       3 sns.heatmap(corrmat, annot = True,vmin= -0.2, vmax = 0.9, cmap = 'Job Role')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...

# %%
data= data.drop('Job Satisfaction', axis=1)
data_test = data_test.drop('Job Satisfaction', axis=1)

# %%
# Exclude 'MonthlyCharges', 'TotalCharges', and 'tenure'
columns_to_plot = [col for col in data.columns if col not in ['Company Tenure ', 'Company Size','Job Level']]

# Iterate through the selected columns
for col in columns_to_plot:
  value_counts = data[col].value_counts()

  # Create the pie chart
  plt.figure(figsize=(8, 8))
  plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=90)
  plt.title(f'Distribution of {col}')
  plt.axis('equal')
  plt.show()
